# %%
import numpy as np

# %%
list(np.random.randint(1, 100, 12))
# Out:
# [81, 58, 30, 14, 12, 72, 15, 25, 44, 70, 54, 82]

# %%
list(np.random.randint(300, 500, 12))
# Out:
# [345, 314, 391, 301, 351, 431, 373, 472, 318, 410, 361, 476]

# %%
aaa = [27, 60, 19, 57, 75, 76, 14, 58, 12, 7, 97, 9]
aaaa = [81, 58, 30, 14, 12, 72, 15, 25, 44, 70, 54, 82]
bbb = [384, 412, 331, 321, 309, 322, 346, 375, 361, 390, 365, 331]
bbbb = [345, 314, 391, 301, 351, 431, 373, 472, 318, 410, 361, 476]

import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
plt.scatter(aaa, aaaa)
plt.scatter(bbb, bbbb)
plt.title('Scatter of Random numbers')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
